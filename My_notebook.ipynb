# %% [markdown]
# <div style="padding: 4px; background: wheat; border-radius: 4px; text-align: center">
#     <h2>My <b><i>First</i></b> Notebook</h2>
# </div>

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
23 + 45 / 15
# Out:
# 26.0

# %%
[x**2 for x in range(-10, 11)]
# Out:
# [100, 81, 64, 49, 36, 25, 16, 9, 4, 1, 0, 1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
import time

for i in range(5):
    print(i)
    time.sleep(10)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.plot(np.sin(range(30)))
